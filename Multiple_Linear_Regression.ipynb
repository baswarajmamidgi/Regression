# %% [markdown]
# A Multiple linear regresssion is like a simple regression but instead of a single predictive variables
# we are using multiple predictive values and a sinle prediction about dependent variable
#
# Linear regresion y=mx+b
#
# Multiple regression y=b+a1x+a2x+a3x....
#
# In multiple regression the data is multi dimensional

# %%
from sklearn.datasets import load_boston  #boston house dataset
from sklearn import linear_model
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import numpy as np
boston=load_boston()
X=boston.data
y=boston.target

np.shape(x)
# Out:
# (506, 13)

# %%
offset=450
X_train, y_train = X[:offset], y[:offset]
X_test, y_test = X[offset:], y[offset:]


regr = linear_model.LinearRegression() #loading sklearn linear model

regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)
plt.plot(y_test,color='blue', linewidth=3)
plt.show()
plt.figure(1)
plt.plot(y_pred,color='orange', linewidth=3)



plt.show()

# %%
plt.scatter(X_train[:, 0], X_train[:, 1],c=y_train,cmap=plt.cm.Paired)

plt.show()
